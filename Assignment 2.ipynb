# %%
#Q1

x=int(input("Enter 1st number:"))
y=int(input("Enter 2nd number:"))
z=int(input("Enter 3rd number:"))
if x>=y:
    if x>=z:
        print(x," is largest number")
    else:
        print(z," is largest number")
elif y>=x:
    if y>=z:
        print(y," is largest number")
    else:
        print(z," is largest number")
# Out:
# Enter 1st number: 10
# Enter 2nd number: 60
# Enter 3rd number: 70
# 70  is largest number
